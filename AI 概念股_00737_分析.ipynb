# %% [markdown]
# <h1>讀取所有資料
# <h5> 讀取漲跌幅、google trend、成交量、指數、淨值、三大法人

# %%
import pandas as pd

# 漲跌幅
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/00737漲跌幅資訊_2023.csv'
price_df = pd.read_csv(file_path)

# Google Trend
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/00737 Google Trend_2023.csv'
trend_df = pd.read_csv(file_path)

# 成交量
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/00737股價資訊_2023.csv'
volume_df = pd.read_csv(file_path)

# 指數1 - 大盤
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/Index/加權指數_2023.csv'
index_TW_df = pd.read_csv(file_path)

# 指數2 - NASDAQ
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/Index/NASDAQ_2023.csv'
index_NASDAQ_df = pd.read_csv(file_path)

# 指數3 - 道瓊
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/Index/dowjones_2023.csv'
index_DOW_df = pd.read_csv(file_path)

# 指數4 - S&P
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/Index/SP500_2023.csv'
index_SP_df = pd.read_csv(file_path)

# 淨值
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/00737_nav.csv'
nav_df = pd.read_csv(file_path)

# 三大法人
file_path = '/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/00737三大法人資訊_2023.csv'
institution_df = pd.read_csv(file_path)

# %% [markdown]
# <h1>清理＆處理資料
# <h5> 先處理漲跌幅資料<br>
# 1. 只保留df中的交易日期和漲跌幅這兩個欄位<br>
# 2. 將交易日期的格式改為python中的時間格式

# %%
# 1. Keep only the '交易日期' and '漲跌幅' columns
price_df = price_df[['交易日期', '漲跌幅']]

# 2. Convert '交易日期' to datetime format
price_df['交易日期'] = pd.to_datetime(price_df['交易日期'].str.replace("'", ""), format='%y/%m/%d')

price_df = price_df.rename(columns={'交易日期': '日期'})

# Sort price_df by '日期'
price_df = price_df.sort_values(by='日期').reset_index(drop=True)

# Display the first few rows to verify the changes
print(price_df.head())
# Out:
#           日期     漲跌幅
# 0 2023-01-03   0.58%
# 1 2023-01-04   0.29%
# 2 2023-01-05   0.95%
# 3 2023-01-06  -1.14%
# 4 2023-01-09   0.74%

# %% [markdown]
# <h5> 處理成交量<br>
# 1. 只保留df中的日期和成交股數和成交筆數這三個欄位<br>
# 2. 將交易日期的格式改為python中的時間格式<br>
# 3. 計算大戶與散戶比例：股數/筆數

# %%
import pandas as pd

# Function to convert ROC year to AD year
def convert_roc_to_ad(date_str):
    year, month, day = date_str.split('/')
    ad_year = int(year) + 1911
    return f'{ad_year}/{month}/{day}'

# 1. Keep only the '日期', '成交股數', and '成交筆數' columns
volume_df = volume_df[['日期', '成交股數', '成交筆數']]

# Apply the conversion function to the '日期' column
volume_df['日期'] = volume_df['日期'].apply(convert_roc_to_ad)

# Convert '日期' to datetime format
volume_df['日期'] = pd.to_datetime(volume_df['日期'], format='%Y/%m/%d')

# Remove commas from '成交股數' and '成交筆數', then convert to integers
volume_df['成交股數'] = volume_df['成交股數'].str.replace(',', '').astype(int)
volume_df['成交筆數'] = volume_df['成交筆數'].str.replace(',', '').astype(int)

# Add a new column '大戶與散戶比例' calculated as '成交股數' / '成交筆數'
volume_df['大戶與散戶比例'] = volume_df['成交股數'] / volume_df['成交筆數']

# Display the first few rows to verify the changes
print(volume_df.head())
# Out:
#           日期    成交股數  成交筆數     大戶與散戶比例
# 0 2023-01-03  240600   530  453.962264
# 1 2023-01-04  108503   113  960.203540
# 2 2023-01-05  289341   993  291.380665
# 3 2023-01-06  102872   537  191.567970
# 4 2023-01-09  118860   437  271.990847

# %% [markdown]
# <h5> 處理指數資料<br>
# 1. 只保留df中的Date, Close, Volume 這三個欄位<br>

# %%
# TW
index_TW_df = index_TW_df[['Date', 'Close', 'Volume']]
index_TW_df = index_TW_df.rename(columns={'Date': '日期'})
index_TW_df['日期'] = pd.to_datetime(index_TW_df['日期'], format='%Y-%m-%d')
print(index_TW_df.head())

# NASDAQ
index_NASDAQ_df = index_NASDAQ_df[['Date', 'Close', 'Volume']]
index_NASDAQ_df = index_NASDAQ_df.rename(columns={'Date': '日期'})
index_NASDAQ_df['日期'] = pd.to_datetime(index_NASDAQ_df['日期'], format='%Y-%m-%d')
print(index_NASDAQ_df.head())

# DOW
index_DOW_df = index_DOW_df[['Date', 'Close', 'Volume']]
index_DOW_df = index_DOW_df.rename(columns={'Date': '日期'})
index_DOW_df['日期'] = pd.to_datetime(index_DOW_df['日期'], format='%Y-%m-%d')
print(index_DOW_df.head())

# SP
index_SP_df = index_SP_df[['Date', 'Close', 'Volume']]
index_SP_df = index_SP_df.rename(columns={'Date': '日期'})
index_SP_df['日期'] = pd.to_datetime(index_SP_df['日期'], format='%Y-%m-%d')
print(index_SP_df.head())
# Out:
#           日期         Close   Volume
# 0 2023-01-03  14224.120117  1816400
# 1 2023-01-04  14199.129883  2073800
# 2 2023-01-05  14301.049805  2086500
# 3 2023-01-06  14373.339844  1741200
# 4 2023-01-09  14752.209961  2581100
#           日期         Close      Volume
# 0 2023-01-03  10386.980469  4780650000
# 1 2023-01-04  10458.759766  5085380000
# 2 2023-01-05  10305.240234  4764270000
# 3 2023-01-06  10569.290039  5199780000
# 4 2023-01-09  10635.650391  5132190000
#           日期         Close     Volume
# 0 2023-01-03  33136.371094  355930000
# 1 2023-01-04  33269.769531  379400000
# 2 2023-01-05  32930.078125  337920000
# 3 2023-01-06  33630.609375  360740000
# 4 2023-01-09  33517.648438  327840000
#           日期        Close      Volume
# 0 2023-01-03  3824.139893  3959140000
# 1 2023-01-04  3852.969971  4414080000
# 2 2023-01-05  3808.100098  3893450000
# 3 2023-01-06  3895.080078  3923560000
# 4 2023-01-09  3892.090088  4311770000

# %% [markdown]
# <h5> 處理淨值資料<br>
# 1. 將交易日期的格式改為python中的時間格式

# %%
nav_df['年月日'] = pd.to_datetime(nav_df['年月日'], format='%Y/%m/%d')
nav_df = nav_df.rename(columns={'年月日': '日期'})

# Sort nav_df by '日期'
nav_df = nav_df.sort_values(by='日期').reset_index(drop=True)

# Display the first few rows to verify the changes
print(nav_df.head())
# Out:
#           日期  淨值(元)
# 0 2023-01-03  24.18
# 1 2023-01-04  24.46
# 2 2023-01-05  24.11
# 3 2023-01-06  24.33
# 4 2023-01-09  24.70

# %% [markdown]
# <h5> 處理三大法人資料<br>
# 1. 留下「日期」、「外資自營商買賣超股數」、「投信買賣超股數」、「自營商買賣超股數」四個欄位<br>
# 2. 將交易日期的格式改為python中的時間格式

# %%
# 1. Keep only the relevant columns
institution_df = institution_df[['日期', '外資自營商買賣超股數', '投信買賣超股數', '自營商買賣超股數']]

# 2. Convert '日期' to datetime format, assuming all dates are in 2023
institution_df['日期'] = pd.to_datetime('2023-' + institution_df['日期'], format='%Y-%m-%d')

# Display the first few rows to verify the changes
print(institution_df.head())
# Out:
#           日期  外資自營商買賣超股數  投信買賣超股數 自營商買賣超股數
# 0 2023-01-03           0        0    7,033
# 1 2023-01-04           0        0    5,000
# 2 2023-01-05           0        0   17,000
# 3 2023-01-06           0        0  -36,652
# 4 2023-01-09           0        0   -5,000

# %% [markdown]
# <h5> 處理 Google Trend 資料<br>
# 因為現在是以周為單位，使用平均分攤的方式讓每一天都有數值

# %%
import pandas as pd
import numpy as np

# Set the '週' column as datetime
trend_df['週'] = pd.to_datetime(trend_df['週'])

# Set '週' column as the index
trend_df.set_index('週', inplace=True)

# Create a date range from the start to the end date
date_range = pd.date_range(start=trend_df.index.min(), end=trend_df.index.max(), freq='D')

# Reindex the DataFrame to include all dates in the range
trend_df = trend_df.reindex(date_range)

# Interpolate the missing values
trend_df = trend_df.interpolate(method='linear')

# Reset index to have '日期' as a column again
trend_df.reset_index(inplace=True)
trend_df.rename(columns={'index': '日期'}, inplace=True)

# Display the first few rows to verify the changes
print(trend_df.head(15))
# Out:
#            日期         AI   CHATGPT   輝達        台積電
# 0  2023-01-01  14.000000  6.000000  1.0  30.000000
# 1  2023-01-02  14.000000  6.285714  1.0  32.571429
# 2  2023-01-03  14.000000  6.571429  1.0  35.142857
# 3  2023-01-04  14.000000  6.857143  1.0  37.714286
# 4  2023-01-05  14.000000  7.142857  1.0  40.285714
# 5  2023-01-06  14.000000  7.428571  1.0  42.857143
# 6  2023-01-07  14.000000  7.714286  1.0  45.428571
# 7  2023-01-08  14.000000  8.000000  1.0  48.000000
# 8  2023-01-09  13.714286  7.857143  1.0  44.857143
# 9  2023-01-10  13.428571  7.714286  1.0  41.714286
# 10 2023-01-11  13.142857  7.571429  1.0  38.571429
# 11 2023-01-12  12.857143  7.428571  1.0  35.428571
# 12 2023-01-13  12.571429  7.285714  1.0  32.285714
# 13 2023-01-14  12.285714  7.142857  1.0  29.142857
# 14 2023-01-15  12.000000  7.000000  1.0  26.000000

# %% [markdown]
# <h1>資料串接（4-6月）
# <h5> 把所有資料串接在一起，並且漲跌幅（＄）要往未來平移一天，才能確保是在預測

# %%
# 漲跌幅
import pandas as pd

# Filter for data from 2023-04-01 to 2023-06-30
filtered_price_df = price_df[(price_df['日期'] >= '2023-04-01') & (price_df['日期'] <= '2023-06-30')]

# Create the 456_df with '日期' and '漲跌幅' columns from filtered_price_df
df_456 = filtered_price_df[['日期', '漲跌幅']].reset_index(drop=True)

# Display the 456_df
print(df_456.head())
print(df_456.tail())
# Out:
#           日期     漲跌幅
# 0 2023-04-06  -1.13%
# 1 2023-04-07   0.29%
# 2 2023-04-10  -0.07%
# 3 2023-04-11   0.55%
# 4 2023-04-12   0.29%
#            日期     漲跌幅
# 54 2023-06-26  -1.77%
# 55 2023-06-27  -1.74%
# 56 2023-06-28   1.10%
# 57 2023-06-29   1.02%
# 58 2023-06-30   0.42%

# %%
# Google Trend
# Filter the trend_df to match the date range of df_456
filtered_trend_df = trend_df[(trend_df['日期'] >= '2023-04-01') & (trend_df['日期'] <= '2023-06-30')]

# Merge trend_df data into df_456
df_456 = pd.merge(df_456, filtered_trend_df[['日期', 'AI', 'CHATGPT', '輝達', '台積電']], on='日期', how='left')

# Display the resulting df_456
print(df_456.head())
print(df_456.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電
# 0 2023-04-06  -1.13%  25.285714  53.000000  1.0  26.714286
# 1 2023-04-07   0.29%  25.857143  54.000000  1.0  29.142857
# 2 2023-04-10  -0.07%  26.857143  55.428571  1.0  34.714286
# 3 2023-04-11   0.55%  26.714286  54.857143  1.0  35.428571
# 4 2023-04-12   0.29%  26.571429  54.285714  1.0  36.142857
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電
# 54 2023-06-26  -1.77%  33.571429  20.714286  4.857143  26.142857
# 55 2023-06-27  -1.74%  33.142857  20.428571  4.714286  26.285714
# 56 2023-06-28   1.10%  32.714286  20.142857  4.571429  26.428571
# 57 2023-06-29   1.02%  32.285714  19.857143  4.428571  26.571429
# 58 2023-06-30   0.42%  31.857143  19.571429  4.285714  26.714286

# %%
# 成交量
# Filter the trend_df to match the date range of df_456
filtered_volume_df = volume_df[(volume_df['日期'] >= '2023-04-01') & (volume_df['日期'] <= '2023-06-30')]

# Merge trend_df data into df_456
df_456 = pd.merge(df_456, filtered_volume_df[['日期', '成交股數', '成交筆數', '大戶與散戶比例']], on='日期', how='left')

# Display the resulting df_456
print(df_456.head())
print(df_456.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數  \
# 0 2023-04-06  -1.13%  25.285714  53.000000  1.0  26.714286  108511   659
# 1 2023-04-07   0.29%  25.857143  54.000000  1.0  29.142857   54492   196
# 2 2023-04-10  -0.07%  26.857143  55.428571  1.0  34.714286   26345   872
# 3 2023-04-11   0.55%  26.714286  54.857143  1.0  35.428571   33241  1005
# 4 2023-04-12   0.29%  26.571429  54.285714  1.0  36.142857   77936   687
#
#       大戶與散戶比例
# 0  164.660091
# 1  278.020408
# 2   30.212156
# 3   33.075622
# 4  113.443959
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  \
# 54 2023-06-26  -1.77%  33.571429  20.714286  4.857143  26.142857  238898
# 55 2023-06-27  -1.74%  33.142857  20.428571  4.714286  26.285714   62218
# 56 2023-06-28   1.10%  32.714286  20.142857  4.571429  26.428571  165845
# 57 2023-06-29   1.02%  32.285714  19.857143  4.428571  26.571429  257497
# 58 2023-06-30   0.42%  31.857143  19.571429  4.285714  26.714286  202433
#
#     成交筆數     大戶與散戶比例
# 54   955  250.154974
# 55   915   67.997814
# 56   833  199.093637
# 57   737  349.385346
# 58   796  254.312814

# %%
# 指數
# Function to fill missing values with the average of the nearest two dates' values
def fill_missing_values(row, df, column_name):
    if pd.isnull(row[column_name]):
        closest_dates = df['日期'].sub(row['日期']).abs().sort_values().index[:2]
        row[column_name] = df.loc[closest_dates, column_name].mean()
    return row

# TW
filtered_index_TW_df = index_TW_df[(index_TW_df['日期'] >= '2023-04-01') & (index_TW_df['日期'] <= '2023-06-30')]
df_456 = pd.merge(df_456, filtered_index_TW_df[['日期', 'Close', 'Volume']], on='日期', how='left')
df_456.rename(columns={'Close': 'TW_Close', 'Volume': 'TW_Volume'}, inplace=True)

# NASDAQ
filtered_index_NASDAQ_df = index_NASDAQ_df[(index_NASDAQ_df['日期'] >= '2023-04-01') & (index_NASDAQ_df['日期'] <= '2023-06-30')]
df_456 = pd.merge(df_456, filtered_index_NASDAQ_df[['日期', 'Close', 'Volume']], on='日期', how='left')
df_456.rename(columns={'Close': 'NASDAQ_Close', 'Volume': 'NASDAQ_Volume'}, inplace=True)
# 填補缺失值
df_456 = df_456.apply(fill_missing_values, axis=1, df=df_456, column_name='NASDAQ_Close')
df_456 = df_456.apply(fill_missing_values, axis=1, df=df_456, column_name='NASDAQ_Volume')

# DOW JONES
filtered_index_DOW_df = index_DOW_df[(index_DOW_df['日期'] >= '2023-04-01') & (index_DOW_df['日期'] <= '2023-06-30')]
df_456 = pd.merge(df_456, filtered_index_DOW_df[['日期', 'Close', 'Volume']], on='日期', how='left')
df_456.rename(columns={'Close': 'DOW_Close', 'Volume': 'DOW_Volume'}, inplace=True)
# 填補缺失值
df_456 = df_456.apply(fill_missing_values, axis=1, df=df_456, column_name='DOW_Close')
df_456 = df_456.apply(fill_missing_values, axis=1, df=df_456, column_name='DOW_Volume')

# S&P500
filtered_index_SP_df = index_SP_df[(index_SP_df['日期'] >= '2023-04-01') & (index_SP_df['日期'] <= '2023-06-30')]
df_456 = pd.merge(df_456, filtered_index_SP_df[['日期', 'Close', 'Volume']], on='日期', how='left')
df_456.rename(columns={'Close': 'SP_Close', 'Volume': 'SP_Volume'}, inplace=True)
# 填補缺失值
df_456 = df_456.apply(fill_missing_values, axis=1, df=df_456, column_name='SP_Close')
df_456 = df_456.apply(fill_missing_values, axis=1, df=df_456, column_name='SP_Volume')

# Display the resulting df_456
print(df_456.head())
print(df_456.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數  \
# 0 2023-04-06  -1.13%  25.285714  53.000000  1.0  26.714286  108511   659
# 1 2023-04-07   0.29%  25.857143  54.000000  1.0  29.142857   54492   196
# 2 2023-04-10  -0.07%  26.857143  55.428571  1.0  34.714286   26345   872
# 3 2023-04-11   0.55%  26.714286  54.857143  1.0  35.428571   33241  1005
# 4 2023-04-12   0.29%  26.571429  54.285714  1.0  36.142857   77936   687
#
#       大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 0  164.660091  15810.769531    2513500  12087.959961   3.862800e+09
# 1  278.020408  15836.500000    2199900  12087.959961   3.862800e+09
# 2   30.212156  15876.169922    2220400  12084.360352   4.334070e+09
# 3   33.075622  15913.879883    2744200  12031.879883   4.676960e+09
# 4  113.443959  15932.969727    3138100  11929.339844   4.909770e+09
#
#       DOW_Close   DOW_Volume     SP_Close     SP_Volume
# 0  33485.289062  258680000.0  4105.020020  3.486690e+09
# 1  33485.289062  258680000.0  4105.020020  3.486690e+09
# 2  33586.519531  232920000.0  4109.109863  3.423650e+09
# 3  33684.789062  241430000.0  4108.939941  3.665830e+09
# 4  33646.500000  260300000.0  4091.949951  3.633120e+09
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  \
# 54 2023-06-26  -1.77%  33.571429  20.714286  4.857143  26.142857  238898
# 55 2023-06-27  -1.74%  33.142857  20.428571  4.714286  26.285714   62218
# 56 2023-06-28   1.10%  32.714286  20.142857  4.571429  26.428571  165845
# 57 2023-06-29   1.02%  32.285714  19.857143  4.428571  26.571429  257497
# 58 2023-06-30   0.42%  31.857143  19.571429  4.285714  26.714286  202433
#
#     成交筆數     大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 54   955  250.154974  17059.240234    3970000  13335.780273   4.430600e+09
# 55   915   67.997814  16887.900391    4028700  13555.669922   5.053660e+09
# 56   833  199.093637  16935.630859    3256100  13591.750000   4.533270e+09
# 57   737  349.385346  16942.300781    3357100  13591.330078   4.388140e+09
# 58   796  254.312814  16915.539062    3542500  13787.919922   4.661120e+09
#
#        DOW_Close   DOW_Volume     SP_Close     SP_Volume
# 54  33714.710938  265330000.0  4328.819824  3.415030e+09
# 55  33926.738281  293210000.0  4378.410156  3.573500e+09
# 56  33852.660156  268050000.0  4376.859863  3.739330e+09
# 57  34122.421875  279940000.0  4396.439941  3.696660e+09
# 58  34407.601562  351060000.0  4450.379883  3.923450e+09

# %%
# 三大法人
filtered_institution_df = institution_df[(institution_df['日期'] >= '2023-04-01') & (institution_df['日期'] <= '2023-06-30')]
df_456 = pd.merge(df_456, filtered_institution_df[['日期', '外資自營商買賣超股數', '投信買賣超股數', '自營商買賣超股數']], on='日期', how='left')

# 填補缺失值
df_456 = df_456.fillna(0)

# Display the resulting df_456
print(df_456.head())
print(df_456.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數  \
# 0 2023-04-06  -1.13%  25.285714  53.000000  1.0  26.714286  108511   659
# 1 2023-04-07   0.29%  25.857143  54.000000  1.0  29.142857   54492   196
# 2 2023-04-10  -0.07%  26.857143  55.428571  1.0  34.714286   26345   872
# 3 2023-04-11   0.55%  26.714286  54.857143  1.0  35.428571   33241  1005
# 4 2023-04-12   0.29%  26.571429  54.285714  1.0  36.142857   77936   687
#
#       大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 0  164.660091  15810.769531    2513500  12087.959961   3.862800e+09
# 1  278.020408  15836.500000    2199900  12087.959961   3.862800e+09
# 2   30.212156  15876.169922    2220400  12084.360352   4.334070e+09
# 3   33.075622  15913.879883    2744200  12031.879883   4.676960e+09
# 4  113.443959  15932.969727    3138100  11929.339844   4.909770e+09
#
#       DOW_Close   DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  \
# 0  33485.289062  258680000.0  4105.020020  3.486690e+09         0.0      0.0
# 1  33485.289062  258680000.0  4105.020020  3.486690e+09         0.0      0.0
# 2  33586.519531  232920000.0  4109.109863  3.423650e+09         0.0      0.0
# 3  33684.789062  241430000.0  4108.939941  3.665830e+09         0.0      0.0
# 4  33646.500000  260300000.0  4091.949951  3.633120e+09         0.0      0.0
#
#   自營商買賣超股數
# 0  -30,221
# 1   17,485
# 2   -9,272
# 3   14,011
# 4   12,000
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  \
# 54 2023-06-26  -1.77%  33.571429  20.714286  4.857143  26.142857  238898
# 55 2023-06-27  -1.74%  33.142857  20.428571  4.714286  26.285714   62218
# 56 2023-06-28   1.10%  32.714286  20.142857  4.571429  26.428571  165845
# 57 2023-06-29   1.02%  32.285714  19.857143  4.428571  26.571429  257497
# 58 2023-06-30   0.42%  31.857143  19.571429  4.285714  26.714286  202433
#
#     成交筆數     大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 54   955  250.154974  17059.240234    3970000  13335.780273   4.430600e+09
# 55   915   67.997814  16887.900391    4028700  13555.669922   5.053660e+09
# 56   833  199.093637  16935.630859    3256100  13591.750000   4.533270e+09
# 57   737  349.385346  16942.300781    3357100  13591.330078   4.388140e+09
# 58   796  254.312814  16915.539062    3542500  13787.919922   4.661120e+09
#
#        DOW_Close   DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  \
# 54  33714.710938  265330000.0  4328.819824  3.415030e+09         0.0      0.0
# 55  33926.738281  293210000.0  4378.410156  3.573500e+09         0.0      0.0
# 56  33852.660156  268050000.0  4376.859863  3.739330e+09         0.0      0.0
# 57  34122.421875  279940000.0  4396.439941  3.696660e+09         0.0      0.0
# 58  34407.601562  351060000.0  4450.379883  3.923450e+09         0.0      0.0
#
#    自營商買賣超股數
# 54   36,000
# 55        0
# 56        0
# 57  -54,277
# 58    6,958

# %%
# 淨值
filtered_nav_df = nav_df[(nav_df['日期'] >= '2023-04-01') & (nav_df['日期'] <= '2023-06-30')]

# Merge nav_df data into df_456
df_456 = pd.merge(df_456, filtered_nav_df[['日期', '淨值(元)']], on='日期', how='left')

# Function to fill missing values with the average of the nearest two dates' values
def fill_missing_values(row, df, column_name):
    if pd.isnull(row[column_name]):
        closest_dates = df['日期'].sub(row['日期']).abs().sort_values().index[:2]
        row[column_name] = df.loc[closest_dates, column_name].mean()
    return row

# Apply the function to fill missing NAV values
df_456 = df_456.apply(fill_missing_values, axis=1, df=nav_df, column_name='淨值(元)')

# Display the resulting df_456
print(df_456.head())
print(df_456.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數  \
# 0 2023-04-06  -1.13%  25.285714  53.000000  1.0  26.714286  108511   659
# 1 2023-04-07   0.29%  25.857143  54.000000  1.0  29.142857   54492   196
# 2 2023-04-10  -0.07%  26.857143  55.428571  1.0  34.714286   26345   872
# 3 2023-04-11   0.55%  26.714286  54.857143  1.0  35.428571   33241  1005
# 4 2023-04-12   0.29%  26.571429  54.285714  1.0  36.142857   77936   687
#
#       大戶與散戶比例      TW_Close  ...  NASDAQ_Close  NASDAQ_Volume     DOW_Close  \
# 0  164.660091  15810.769531  ...  12087.959961   3.862800e+09  33485.289062
# 1  278.020408  15836.500000  ...  12087.959961   3.862800e+09  33485.289062
# 2   30.212156  15876.169922  ...  12084.360352   4.334070e+09  33586.519531
# 3   33.075622  15913.879883  ...  12031.879883   4.676960e+09  33684.789062
# 4  113.443959  15932.969727  ...  11929.339844   4.909770e+09  33646.500000
#
#     DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數  \
# 0  258680000.0  4105.020020  3.486690e+09         0.0      0.0   -30,221
# 1  258680000.0  4105.020020  3.486690e+09         0.0      0.0    17,485
# 2  232920000.0  4109.109863  3.423650e+09         0.0      0.0    -9,272
# 3  241430000.0  4108.939941  3.665830e+09         0.0      0.0    14,011
# 4  260300000.0  4091.949951  3.633120e+09         0.0      0.0    12,000
#
#    淨值(元)
# 0  27.36
# 1  27.40
# 2  27.44
# 3  27.50
# 4  27.34
#
# [5 rows x 21 columns]
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  \
# 54 2023-06-26  -1.77%  33.571429  20.714286  4.857143  26.142857  238898
# 55 2023-06-27  -1.74%  33.142857  20.428571  4.714286  26.285714   62218
# 56 2023-06-28   1.10%  32.714286  20.142857  4.571429  26.428571  165845
# 57 2023-06-29   1.02%  32.285714  19.857143  4.428571  26.571429  257497
# 58 2023-06-30   0.42%  31.857143  19.571429  4.285714  26.714286  202433
#
#     成交筆數     大戶與散戶比例      TW_Close  ...  NASDAQ_Close  NASDAQ_Volume  \
# 54   955  250.154974  17059.240234  ...  13335.780273   4.430600e+09
# 55   915   67.997814  16887.900391  ...  13555.669922   5.053660e+09
# 56   833  199.093637  16935.630859  ...  13591.750000   4.533270e+09
# 57   737  349.385346  16942.300781  ...  13591.330078   4.388140e+09
# 58   796  254.312814  16915.539062  ...  13787.919922   4.661120e+09
#
#        DOW_Close   DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  \
# 54  33714.710938  265330000.0  4328.819824  3.415030e+09         0.0      0.0
# 55  33926.738281  293210000.0  4378.410156  3.573500e+09         0.0      0.0
# 56  33852.660156  268050000.0  4376.859863  3.739330e+09         0.0      0.0
# 57  34122.421875  279940000.0  4396.439941  3.696660e+09         0.0      0.0
# 58  34407.601562  351060000.0  4450.379883  3.923450e+09         0.0      0.0
#
#     自營商買賣超股數  淨值(元)
# 54    36,000  29.95
# 55         0  30.33
# 56         0  30.67
# 57   -54,277  30.77
# 58     6,958  31.14
#
# [5 rows x 21 columns]

# %%
# 漲跌幅（＄）要往未來平移一天，才能確保是在預測

# Remove the first row from '漲跌幅' column and reindex it
df_456['漲跌幅'] = df_456['漲跌幅'].shift(-1)

# Remove the last row
df_456 = df_456.iloc[:-1]

# Drop rows where '漲跌幅' is NaN (which would only be the last row now)
df_456 = df_456.dropna(subset=['漲跌幅'])

# Convert "漲跌幅" column to numeric
df_456['漲跌幅'] = df_456['漲跌幅'].str.replace('%', '').astype(float) / 100

df_456 = df_456.drop("日期", axis = 1)

# Display the resulting df_456
print(df_456.head())
print(df_456.tail())
# Out:
#       漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數     大戶與散戶比例  \
# 0   0.29%  25.285714  53.000000  1.0  26.714286  108511   659  164.660091
# 1  -0.07%  25.857143  54.000000  1.0  29.142857   54492   196  278.020408
# 2   0.55%  26.857143  55.428571  1.0  34.714286   26345   872   30.212156
# 3   0.29%  26.714286  54.857143  1.0  35.428571   33241  1005   33.075622
# 4  -0.44%  26.571429  54.285714  1.0  36.142857   77936   687  113.443959
#
#        TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume     DOW_Close  \
# 0  15810.769531    2513500  12087.959961   3.862800e+09  33485.289062
# 1  15836.500000    2199900  12087.959961   3.862800e+09  33485.289062
# 2  15876.169922    2220400  12084.360352   4.334070e+09  33586.519531
# 3  15913.879883    2744200  12031.879883   4.676960e+09  33684.789062
# 4  15932.969727    3138100  11929.339844   4.909770e+09  33646.500000
#
#     DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數 自營商買賣超股數  淨值(元)
# 0  258680000.0  4105.020020  3.486690e+09         0.0      0.0  -30,221  27.36
# 1  258680000.0  4105.020020  3.486690e+09         0.0      0.0   17,485  27.40
# 2  232920000.0  4109.109863  3.423650e+09         0.0      0.0   -9,272  27.44
# 3  241430000.0  4108.939941  3.665830e+09         0.0      0.0   14,011  27.50
# 4  260300000.0  4091.949951  3.633120e+09         0.0      0.0   12,000  27.34
#        漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  成交筆數  \
# 53  -1.77%  32.285714  21.571429  4.428571  22.571429   95776   732
# 54  -1.74%  33.571429  20.714286  4.857143  26.142857  238898   955
# 55   1.10%  33.142857  20.428571  4.714286  26.285714   62218   915
# 56   1.02%  32.714286  20.142857  4.571429  26.428571  165845   833
# 57   0.42%  32.285714  19.857143  4.428571  26.571429  257497   737
#
#        大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 53  130.841530  17202.400391    4354900  13502.200195   5.194640e+09
# 54  250.154974  17059.240234    3970000  13335.780273   4.430600e+09
# 55   67.997814  16887.900391    4028700  13555.669922   5.053660e+09
# 56  199.093637  16935.630859    3256100  13591.750000   4.533270e+09
# 57  349.385346  16942.300781    3357100  13591.330078   4.388140e+09
#
#        DOW_Close   DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  \
# 53  33951.519531  323690000.0  4365.689941  3.709330e+09         0.0      0.0
# 54  33714.710938  265330000.0  4328.819824  3.415030e+09         0.0      0.0
# 55  33926.738281  293210000.0  4378.410156  3.573500e+09         0.0      0.0
# 56  33852.660156  268050000.0  4376.859863  3.739330e+09         0.0      0.0
# 57  34122.421875  279940000.0  4396.439941  3.696660e+09         0.0      0.0
#
#    自營商買賣超股數  淨值(元)
# 53   31,827  30.67
# 54   36,000  29.95
# 55        0  30.33
# 56        0  30.67
# 57  -54,277  30.77

# %%
# 存檔備份
df_456.to_csv("/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/df_456.csv")

# %% [markdown]
# <h1>資料分析
# <h5> 分別分析 5、7、10 天為區間，漲跌幅與各個指標的相關性

# %%
# 以 5 天為群組

import pandas as pd

# Create an empty DataFrame for storing correlations
columns_456 = df_456.columns
df_456_5day_corr = pd.DataFrame(columns=columns_456[1:])

# Define a function to calculate correlations
def calculate_correlations(df, corr_df, group_size):
    n_rows = df.shape[0]
    for i in range(0, n_rows, group_size):
        df_group = df.iloc[i:i + group_size]
        if df_group.shape[0] > 1:  # Ensure there are at least two rows to calculate correlation
            corr = df_group.corr()
            first_row = corr.iloc[0]
            first_row_df = pd.DataFrame(first_row).T
            corr_df = pd.concat([corr_df, first_row_df], ignore_index=True)
    return corr_df

# Calculate correlations for "AI" column
df_456_5day_corr = calculate_correlations(df_456, df_456_5day_corr, 5)

# 空值補0
df_456_5day_corr = df_456_5day_corr.fillna(0)

# Drop "漲跌幅" column
df_456_5day_corr = df_456_5day_corr.drop(columns=['漲跌幅'], errors='ignore')

# Save the result to a CSV file
df_456_5day_corr.to_csv('/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/df_456_5day_corr.csv', index=False)

# Display the result
print(df_456_5day_corr)
# Out:
#           AI   CHATGPT        輝達       台積電      成交股數      成交筆數   大戶與散戶比例  \
# 0   0.068895  0.300203  0.000000 -0.143596 -0.380724  0.470121 -0.454937
# 1   0.130419  0.817167  0.000000 -0.686647  0.571734 -0.117409  0.629356
# 2   0.709140  0.794492  0.000000  0.793788 -0.058481  0.007670 -0.048843
# 3   0.761771  0.812999  0.000000  0.751749  0.219022  0.191220 -0.030366
# 4  -0.550486  0.475020 -0.475020 -0.540117  0.300292 -0.260475  0.427977
# 5   0.832063 -0.851381  0.839411  0.816650  0.883419  0.011141  0.466144
# 6   0.054237 -0.152568  0.105777  0.036559 -0.757618 -0.270543 -0.312714
# 7  -0.026061  0.220403  0.265140  0.147251 -0.917757 -0.670761 -0.749903
# 8   0.031683  0.357333  0.298603 -0.323679 -0.295245 -0.646272  0.163565
# 9   0.722638  0.357702  0.400951  0.517754 -0.490147 -0.742802  0.210948
# 10 -0.601710  0.682576 -0.765883 -0.244513  0.330175 -0.681065  0.520908
# 11  0.914807  0.914807  0.914807 -0.914807 -0.899944  0.932187 -0.929994
#
#     TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  DOW_Close  DOW_Volume  \
# 0  -0.367317  -0.626169      0.745276      -0.350026  -0.104447   -0.769037
# 1   0.018626   0.594358      0.243324       0.007035   0.758831    0.558694
# 2   0.703705   0.266816      0.860477      -0.248507   0.604374   -0.113933
# 3  -0.518217   0.292795      0.779120      -0.027852   0.689057    0.944893
# 4   0.161274  -0.900570      0.043490       0.688748   0.634749    0.319888
# 5   0.747279   0.647308      0.876199       0.635849   0.708151    0.782511
# 6   0.228260   0.203720      0.682599       0.216788   0.106226    0.024166
# 7  -0.570957  -0.645115      0.305587      -0.835293   0.837074   -0.684455
# 8  -0.958810   0.492425      0.973717      -0.840041   0.111882   -0.194488
# 9  -0.346953  -0.571759     -0.220994      -0.311634   0.050808   -0.324572
# 10  0.744805   0.672032      0.909030       0.680043   0.856843    0.687760
# 11 -0.677287   0.488952     -0.582088       0.744848  -0.929840    0.139038
#
#     SP_Close  SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數     淨值(元)
# 0   0.902113  -0.495280         0.0      0.0         0  0.615790
# 1  -0.380657   0.259952         0.0      0.0         0  0.451624
# 2   0.728025  -0.427305         0.0      0.0         0  0.817478
# 3   0.709189  -0.672335         0.0      0.0         0  0.670745
# 4   0.649360   0.805574         0.0      0.0         0 -0.047821
# 5   0.850627   0.792100         0.0      0.0         0  0.904068
# 6   0.451539  -0.547928         0.0      0.0         0  0.808345
# 7   0.619220  -0.808676         0.0      0.0         0 -0.473483
# 8   0.742933  -0.610329         0.0      0.0         0  0.084727
# 9  -0.246162  -0.085814         0.0      0.0         0 -0.141277
# 10  0.893576   0.710369         0.0      0.0         0  0.859546
# 11 -0.984003  -0.371902         0.0      0.0         0 -0.751244

# %%
# 以 7 天為群組

# Create an empty DataFrame for storing correlations
columns_456 = df_456.columns
df_456_7day_corr = pd.DataFrame(columns=columns_456[1:])

# Define a function to calculate correlations
def calculate_correlations(df, corr_df, group_size):
    n_rows = df.shape[0]
    for i in range(0, n_rows, group_size):
        df_group = df.iloc[i:i + group_size]
        if df_group.shape[0] > 1:  # Ensure there are at least two rows to calculate correlation
            corr = df_group.corr()
            first_row = corr.iloc[0]
            first_row_df = pd.DataFrame(first_row).T
            corr_df = pd.concat([corr_df, first_row_df], ignore_index=True)
    return corr_df

# Calculate correlations for "AI" column
df_456_7day_corr = calculate_correlations(df_456, df_456_7day_corr, 7)

# 空值補0
df_456_7day_corr = df_456_7day_corr.fillna(0)

# Drop "漲跌幅" column
df_456_7day_corr = df_456_7day_corr.drop(columns=['漲跌幅'], errors='ignore')

# Save the result to a CSV file
df_456_7day_corr.to_csv('/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/df_456_7day_corr.csv', index=False)

# Display the result
print(df_456_7day_corr)
# Out:
#          AI   CHATGPT        輝達       台積電      成交股數      成交筆數   大戶與散戶比例  \
# 0  0.130119  0.066174  0.000000  0.137886  0.285368  0.298273 -0.069445
# 1 -0.114548  0.736109  0.000000  0.701062 -0.007021  0.025058 -0.231241
# 2  0.084157  0.027199  0.000000  0.089704  0.022021 -0.044153  0.113955
# 3  0.111200 -0.021245  0.092218  0.012255 -0.490045  0.140962 -0.290166
# 4 -0.588057  0.278180 -0.623681 -0.567437 -0.698229 -0.402840 -0.351646
# 5 -0.013547  0.100653  0.131150  0.071855 -0.873410 -0.642622 -0.678588
# 6  0.521702 -0.320003 -0.263258  0.021633 -0.441246 -0.722931  0.153800
# 7  0.098576  0.335584 -0.086917  0.395025 -0.126666  0.064193 -0.067163
# 8  1.000000  1.000000  1.000000 -1.000000 -1.000000  1.000000 -1.000000
#
#    TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  DOW_Close  DOW_Volume  \
# 0 -0.599148   0.249570      0.757602       0.129272   0.495177    0.032040
# 1  0.744472   0.157799      0.647592      -0.016596   0.712599   -0.408816
# 2  0.132446  -0.213520      0.828376      -0.401281   0.651632    0.691145
# 3  0.084524  -0.768995      0.295755       0.372231   0.335256   -0.037804
# 4 -0.535363   0.009142      0.281241       0.507413   0.571179    0.259843
# 5 -0.320120  -0.553252      0.147327      -0.731645   0.184520   -0.678084
# 6  0.099044  -0.029736      0.592672      -0.224209   0.595267   -0.449796
# 7 -0.169733   0.210913      0.616796       0.282050   0.508890    0.211595
# 8 -1.000000  -1.000000      1.000000       1.000000  -1.000000   -1.000000
#
#    SP_Close  SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數     淨值(元)
# 0  0.672648  -0.168116         0.0      0.0         0  0.624589
# 1  0.609024  -0.298874         0.0      0.0         0  0.765610
# 2  0.745139  -0.350029         0.0      0.0         0  0.776395
# 3  0.582816   0.456123         0.0      0.0         0  0.527129
# 4  0.519917  -0.227681         0.0      0.0         0 -0.063925
# 5  0.218795  -0.743648         0.0      0.0         0 -0.237807
# 6  0.549403  -0.598782         0.0      0.0         0  0.438184
# 7  0.656597   0.206952         0.0      0.0         0  0.346511
# 8 -1.000000   1.000000         0.0      0.0         0 -1.000000

# %%
# 以 10 天為群組

import pandas as pd

# Create an empty DataFrame for storing correlations
columns_456 = df_456.columns
df_456_10day_corr = pd.DataFrame(columns=columns_456[1:])

# Define a function to calculate correlations
def calculate_correlations(df, corr_df, group_size):
    n_rows = df.shape[0]
    for i in range(0, n_rows, group_size):
        df_group = df.iloc[i:i + group_size]
        if df_group.shape[0] > 1:  # Ensure there are at least two rows to calculate correlation
            corr = df_group.corr()
            first_row = corr.iloc[0]
            first_row_df = pd.DataFrame(first_row).T
            corr_df = pd.concat([corr_df, first_row_df], ignore_index=True)
    return corr_df

# Calculate correlations for "AI" column
df_456_10day_corr = calculate_correlations(df_456, df_456_10day_corr, 10)

# 空值補0
df_456_10day_corr = df_456_10day_corr.fillna(0)

# Drop "漲跌幅" column
df_456_10day_corr = df_456_10day_corr.drop(columns=['漲跌幅'], errors='ignore')

# Save the result to a CSV file
df_456_10day_corr.to_csv('/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/df_456_10day_corr.csv', index=False)

# Display the result
print(df_456_10day_corr)
# Out:
#          AI   CHATGPT        輝達       台積電      成交股數      成交筆數   大戶與散戶比例  \
# 0  0.054989  0.460948  0.000000 -0.134679  0.226865  0.126588  0.056884
# 1 -0.204465 -0.130521  0.000000 -0.198499  0.063321  0.317273 -0.246036
# 2  0.556936 -0.266922  0.539213  0.139497  0.281185 -0.136562  0.316842
# 3  0.230119  0.157291  0.208602  0.236593 -0.639179 -0.330946 -0.366665
# 4  0.406062 -0.119418  0.083877  0.071379 -0.427524 -0.711256  0.175936
# 5  0.024170 -0.174613  0.009488  0.457334 -0.139743  0.004960 -0.088119
#
#    TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  DOW_Close  DOW_Volume  \
# 0 -0.091992  -0.058755      0.269676      -0.149409   0.092298    0.141303
# 1 -0.029813  -0.083664      0.729747       0.245813   0.543158    0.746217
# 2  0.617574   0.162861      0.617238       0.516378   0.457649    0.600820
# 3  0.233807  -0.075385      0.442942      -0.243587   0.179208   -0.342194
# 4 -0.013945  -0.023211      0.349415      -0.241516   0.317778   -0.277782
# 5 -0.589133  -0.245336      0.493819      -0.010924   0.221158   -0.030880
#
#    SP_Close  SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數     淨值(元)
# 0  0.015926  -0.198921         0.0      0.0         0  0.158091
# 1  0.615207  -0.076662         0.0      0.0         0  0.216400
# 2  0.759914   0.693273         0.0      0.0         0  0.615807
# 3  0.509830  -0.498914         0.0      0.0         0  0.306376
# 4  0.271510  -0.453689         0.0      0.0         0  0.232995
# 5  0.543466   0.061335         0.0      0.0         0  0.166547

# %% [markdown]
# <h1>資料串接（10-12月）
# <h5> 把所有資料串接在一起，並且漲跌幅（＄）要往未來平移一天，才能確保是在預測

# %%
# 漲跌幅
import pandas as pd

# Filter for data from 2023-10-01 to 2023-12-31
filtered_price_df = price_df[(price_df['日期'] >= '2023-10-01') & (price_df['日期'] <= '2023-12-31')]

# Create the df_101112 with '日期' and '漲跌幅' columns from filtered_price_df
df_101112 = filtered_price_df[['日期', '漲跌幅']].reset_index(drop=True)

# Display the df_101112
print(df_101112.head())
print(df_101112.tail())
# Out:
#           日期     漲跌幅
# 0 2023-10-02   1.30%
# 1 2023-10-03  -0.83%
# 2 2023-10-04  -2.03%
# 3 2023-10-05   0.32%
# 4 2023-10-06  -0.75%
#            日期     漲跌幅
# 58 2023-12-25   0.58%
# 59 2023-12-26  -0.23%
# 60 2023-12-27   0.19%
# 61 2023-12-28      0%
# 62 2023-12-29  -0.19%

# %%
# Google Trend
# Filter the trend_df to match the date range of df_101112
filtered_trend_df = trend_df[(trend_df['日期'] >= '2023-10-01') & (trend_df['日期'] <= '2023-12-31')]

# Merge trend_df data into df_101112
df_101112 = pd.merge(df_101112, filtered_trend_df[['日期', 'AI', 'CHATGPT', '輝達', '台積電']], on='日期', how='left')

# Display the resulting df_101112
print(df_101112.head())
print(df_101112.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電
# 0 2023-10-02   1.30%  34.857143  24.571429  6.0  21.714286
# 1 2023-10-03  -0.83%  33.714286  24.142857  6.0  21.428571
# 2 2023-10-04  -2.03%  32.571429  23.714286  6.0  21.142857
# 3 2023-10-05   0.32%  31.428571  23.285714  6.0  20.857143
# 4 2023-10-06  -0.75%  30.285714  22.857143  6.0  20.571429
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電
# 58 2023-12-25   0.58%  38.571429  38.571429  3.857143  21.142857
# 59 2023-12-26  -0.23%  38.142857  38.142857  3.714286  21.285714
# 60 2023-12-27   0.19%  37.714286  37.714286  3.571429  21.428571
# 61 2023-12-28      0%  37.285714  37.285714  3.428571  21.571429
# 62 2023-12-29  -0.19%  36.857143  36.857143  3.285714  21.714286

# %%
# 成交量
# Filter the trend_df to match the date range of df_101112
filtered_volume_df = volume_df[(volume_df['日期'] >= '2023-10-01') & (volume_df['日期'] <= '2023-12-31')]

# Merge trend_df data into df_101112
df_101112 = pd.merge(df_101112, filtered_volume_df[['日期', '成交股數', '成交筆數', '大戶與散戶比例']], on='日期', how='left')

# Display the resulting df_101112
print(df_101112.head())
print(df_101112.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數  \
# 0 2023-10-02   1.30%  34.857143  24.571429  6.0  21.714286   34512   837
# 1 2023-10-03  -0.83%  33.714286  24.142857  6.0  21.428571   31862   965
# 2 2023-10-04  -2.03%  32.571429  23.714286  6.0  21.142857  249091    90
# 3 2023-10-05   0.32%  31.428571  23.285714  6.0  20.857143  428305   637
# 4 2023-10-06  -0.75%  30.285714  22.857143  6.0  20.571429  118427   450
#
#        大戶與散戶比例
# 0    41.232975
# 1    33.017617
# 2  2767.677778
# 3   672.378336
# 4   263.171111
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  \
# 58 2023-12-25   0.58%  38.571429  38.571429  3.857143  21.142857   69902
# 59 2023-12-26  -0.23%  38.142857  38.142857  3.714286  21.285714  188060
# 60 2023-12-27   0.19%  37.714286  37.714286  3.571429  21.428571  418101
# 61 2023-12-28      0%  37.285714  37.285714  3.428571  21.571429  309021
# 62 2023-12-29  -0.19%  36.857143  36.857143  3.285714  21.714286  166076
#
#     成交筆數     大戶與散戶比例
# 58   627  111.486443
# 59   941  199.851222
# 60   443  943.794582
# 61   416  742.838942
# 62   544  305.286765

# %%
# 指數
# Function to fill missing values with the average of the nearest two dates' values
def fill_missing_values(row, df, column_name):
    if pd.isnull(row[column_name]):
        closest_dates = df['日期'].sub(row['日期']).abs().sort_values().index[:2]
        row[column_name] = df.loc[closest_dates, column_name].mean()
    return row

# TW
filtered_index_TW_df = index_TW_df[(index_TW_df['日期'] >= '2023-10-01') & (index_TW_df['日期'] <= '2023-12-31')]
df_101112 = pd.merge(df_101112, filtered_index_TW_df[['日期', 'Close', 'Volume']], on='日期', how='left')
df_101112.rename(columns={'Close': 'TW_Close', 'Volume': 'TW_Volume'}, inplace=True)

# NASDAQ
filtered_index_NASDAQ_df = index_NASDAQ_df[(index_NASDAQ_df['日期'] >= '2023-10-01') & (index_NASDAQ_df['日期'] <= '2023-12-31')]
df_101112 = pd.merge(df_101112, filtered_index_NASDAQ_df[['日期', 'Close', 'Volume']], on='日期', how='left')
df_101112.rename(columns={'Close': 'NASDAQ_Close', 'Volume': 'NASDAQ_Volume'}, inplace=True)
# 填補缺失值
df_101112 = df_101112.apply(fill_missing_values, axis=1, df=df_101112, column_name='NASDAQ_Close')
df_101112 = df_101112.apply(fill_missing_values, axis=1, df=df_101112, column_name='NASDAQ_Volume')

# DOW JONES
filtered_index_DOW_df = index_DOW_df[(index_DOW_df['日期'] >= '2023-10-01') & (index_DOW_df['日期'] <= '2023-12-31')]
df_101112 = pd.merge(df_101112, filtered_index_DOW_df[['日期', 'Close', 'Volume']], on='日期', how='left')
df_101112.rename(columns={'Close': 'DOW_Close', 'Volume': 'DOW_Volume'}, inplace=True)
# 填補缺失值
df_101112 = df_101112.apply(fill_missing_values, axis=1, df=df_101112, column_name='DOW_Close')
df_101112 = df_101112.apply(fill_missing_values, axis=1, df=df_101112, column_name='DOW_Volume')

# S&P500
filtered_index_SP_df = index_SP_df[(index_SP_df['日期'] >= '2023-10-01') & (index_SP_df['日期'] <= '2023-12-31')]
df_101112 = pd.merge(df_101112, filtered_index_SP_df[['日期', 'Close', 'Volume']], on='日期', how='left')
df_101112.rename(columns={'Close': 'SP_Close', 'Volume': 'SP_Volume'}, inplace=True)
# 填補缺失值
df_101112 = df_101112.apply(fill_missing_values, axis=1, df=df_101112, column_name='SP_Close')
df_101112 = df_101112.apply(fill_missing_values, axis=1, df=df_101112, column_name='SP_Volume')

# Display the resulting df_101112
print(df_101112.head())
print(df_101112.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數  \
# 0 2023-10-02   1.30%  34.857143  24.571429  6.0  21.714286   34512   837
# 1 2023-10-03  -0.83%  33.714286  24.142857  6.0  21.428571   31862   965
# 2 2023-10-04  -2.03%  32.571429  23.714286  6.0  21.142857  249091    90
# 3 2023-10-05   0.32%  31.428571  23.285714  6.0  20.857143  428305   637
# 4 2023-10-06  -0.75%  30.285714  22.857143  6.0  20.571429  118427   450
#
#        大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 0    41.232975  16557.310547    2669600  13307.769531   4.554700e+09
# 1    33.017617  16454.339844    2697100  13059.469727   4.684310e+09
# 2  2767.677778  16273.379883    2624800  13236.009766   4.308070e+09
# 3   672.378336  16453.519531    2503200  13219.830078   4.167470e+09
# 4   263.171111  16520.570312    2296800  13431.339844   4.309420e+09
#
#       DOW_Close   DOW_Volume     SP_Close     SP_Volume
# 0  33433.351562  275630000.0  4288.390137  3.938660e+09
# 1  33002.378906  293450000.0  4229.450195  3.953830e+09
# 2  33129.550781  287030000.0  4263.750000  3.777600e+09
# 3  33119.570312  277250000.0  4258.189941  3.581470e+09
# 4  33407.578125  332990000.0  4308.500000  3.902030e+09
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  \
# 58 2023-12-25   0.58%  38.571429  38.571429  3.857143  21.142857   69902
# 59 2023-12-26  -0.23%  38.142857  38.142857  3.714286  21.285714  188060
# 60 2023-12-27   0.19%  37.714286  37.714286  3.571429  21.428571  418101
# 61 2023-12-28      0%  37.285714  37.285714  3.428571  21.571429  309021
# 62 2023-12-29  -0.19%  36.857143  36.857143  3.285714  21.714286  166076
#
#     成交筆數     大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 58   627  111.486443  17604.839844    3027400  15074.570312   6.120600e+09
# 59   941  199.851222  17751.730469    2900000  15074.570312   6.120600e+09
# 60   443  943.794582  17891.500000    3378000  15099.179688   7.480170e+09
# 61   416  742.838942  17910.369141    3289700  15095.139648   5.090570e+09
# 62   544  305.286765  17930.810547    2868000  15011.349609   5.441060e+09
#
#        DOW_Close   DOW_Volume     SP_Close     SP_Volume
# 58  37545.328125  212420000.0  4774.750000  2.513910e+09
# 59  37545.328125  212420000.0  4774.750000  2.513910e+09
# 60  37656.519531  245530000.0  4781.580078  2.748450e+09
# 61  37710.101562  199550000.0  4783.350098  2.698860e+09
# 62  37689.539062  234570000.0  4769.830078  3.126060e+09

# %%
# 三大法人
filtered_institution_df = institution_df[(institution_df['日期'] >= '2023-10-01') & (institution_df['日期'] <= '2023-12-31')]
df_101112 = pd.merge(df_101112, filtered_institution_df[['日期', '外資自營商買賣超股數', '投信買賣超股數', '自營商買賣超股數']], on='日期', how='left')

# 填補缺失值
df_101112 = df_101112.fillna(0)

# Display the resulting df_101112
print(df_101112.head())
print(df_101112.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數  \
# 0 2023-10-02   1.30%  34.857143  24.571429  6.0  21.714286   34512   837
# 1 2023-10-03  -0.83%  33.714286  24.142857  6.0  21.428571   31862   965
# 2 2023-10-04  -2.03%  32.571429  23.714286  6.0  21.142857  249091    90
# 3 2023-10-05   0.32%  31.428571  23.285714  6.0  20.857143  428305   637
# 4 2023-10-06  -0.75%  30.285714  22.857143  6.0  20.571429  118427   450
#
#        大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 0    41.232975  16557.310547    2669600  13307.769531   4.554700e+09
# 1    33.017617  16454.339844    2697100  13059.469727   4.684310e+09
# 2  2767.677778  16273.379883    2624800  13236.009766   4.308070e+09
# 3   672.378336  16453.519531    2503200  13219.830078   4.167470e+09
# 4   263.171111  16520.570312    2296800  13431.339844   4.309420e+09
#
#       DOW_Close   DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  \
# 0  33433.351562  275630000.0  4288.390137  3.938660e+09           0        0
# 1  33002.378906  293450000.0  4229.450195  3.953830e+09           0        0
# 2  33129.550781  287030000.0  4263.750000  3.777600e+09           0        0
# 3  33119.570312  277250000.0  4258.189941  3.581470e+09           0        0
# 4  33407.578125  332990000.0  4308.500000  3.902030e+09           0        0
#
#    自營商買賣超股數
# 0   -11,165
# 1   -14,138
# 2   -63,000
# 3  -271,452
# 4   -44,029
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  \
# 58 2023-12-25   0.58%  38.571429  38.571429  3.857143  21.142857   69902
# 59 2023-12-26  -0.23%  38.142857  38.142857  3.714286  21.285714  188060
# 60 2023-12-27   0.19%  37.714286  37.714286  3.571429  21.428571  418101
# 61 2023-12-28      0%  37.285714  37.285714  3.428571  21.571429  309021
# 62 2023-12-29  -0.19%  36.857143  36.857143  3.285714  21.714286  166076
#
#     成交筆數     大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 58   627  111.486443  17604.839844    3027400  15074.570312   6.120600e+09
# 59   941  199.851222  17751.730469    2900000  15074.570312   6.120600e+09
# 60   443  943.794582  17891.500000    3378000  15099.179688   7.480170e+09
# 61   416  742.838942  17910.369141    3289700  15095.139648   5.090570e+09
# 62   544  305.286765  17930.810547    2868000  15011.349609   5.441060e+09
#
#        DOW_Close   DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  \
# 58  37545.328125  212420000.0  4774.750000  2.513910e+09           0        0
# 59  37545.328125  212420000.0  4774.750000  2.513910e+09           0        0
# 60  37656.519531  245530000.0  4781.580078  2.748450e+09           0        0
# 61  37710.101562  199550000.0  4783.350098  2.698860e+09           0        0
# 62  37689.539062  234570000.0  4769.830078  3.126060e+09           0        0
#
#     自營商買賣超股數
# 58       117
# 59   115,701
# 60   -74,290
# 61   -95,342
# 62  -107,050

# %%
# 淨值
filtered_nav_df = nav_df[(nav_df['日期'] >= '2023-10-01') & (nav_df['日期'] <= '2023-12-31')]

# Merge nav_df data into df_101112
df_101112 = pd.merge(df_101112, filtered_nav_df[['日期', '淨值(元)']], on='日期', how='left')

# Function to fill missing values with the average of the nearest two dates' values
def fill_missing_values(row, df, column_name):
    if pd.isnull(row[column_name]):
        closest_dates = df['日期'].sub(row['日期']).abs().sort_values().index[:2]
        row[column_name] = df.loc[closest_dates, column_name].mean()
    return row

# Apply the function to fill missing NAV values
df_101112 = df_101112.apply(fill_missing_values, axis=1, df=nav_df, column_name='淨值(元)')

# Display the resulting df_101112
print(df_101112.head())
print(df_101112.tail())
# Out:
#           日期     漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數  \
# 0 2023-10-02   1.30%  34.857143  24.571429  6.0  21.714286   34512   837
# 1 2023-10-03  -0.83%  33.714286  24.142857  6.0  21.428571   31862   965
# 2 2023-10-04  -2.03%  32.571429  23.714286  6.0  21.142857  249091    90
# 3 2023-10-05   0.32%  31.428571  23.285714  6.0  20.857143  428305   637
# 4 2023-10-06  -0.75%  30.285714  22.857143  6.0  20.571429  118427   450
#
#        大戶與散戶比例      TW_Close  ...  NASDAQ_Close  NASDAQ_Volume     DOW_Close  \
# 0    41.232975  16557.310547  ...  13307.769531   4.554700e+09  33433.351562
# 1    33.017617  16454.339844  ...  13059.469727   4.684310e+09  33002.378906
# 2  2767.677778  16273.379883  ...  13236.009766   4.308070e+09  33129.550781
# 3   672.378336  16453.519531  ...  13219.830078   4.167470e+09  33119.570312
# 4   263.171111  16520.570312  ...  13431.339844   4.309420e+09  33407.578125
#
#     DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數  \
# 0  275630000.0  4288.390137  3.938660e+09           0        0   -11,165
# 1  293450000.0  4229.450195  3.953830e+09           0        0   -14,138
# 2  287030000.0  4263.750000  3.777600e+09           0        0   -63,000
# 3  277250000.0  4258.189941  3.581470e+09           0        0  -271,452
# 4  332990000.0  4308.500000  3.902030e+09           0        0   -44,029
#
#    淨值(元)
# 0  28.49
# 1  27.94
# 2  28.02
# 3  27.81
# 4  28.17
#
# [5 rows x 21 columns]
#            日期     漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  \
# 58 2023-12-25   0.58%  38.571429  38.571429  3.857143  21.142857   69902
# 59 2023-12-26  -0.23%  38.142857  38.142857  3.714286  21.285714  188060
# 60 2023-12-27   0.19%  37.714286  37.714286  3.571429  21.428571  418101
# 61 2023-12-28      0%  37.285714  37.285714  3.428571  21.571429  309021
# 62 2023-12-29  -0.19%  36.857143  36.857143  3.285714  21.714286  166076
#
#     成交筆數     大戶與散戶比例      TW_Close  ...  NASDAQ_Close  NASDAQ_Volume  \
# 58   627  111.486443  17604.839844  ...  15074.570312   6.120600e+09
# 59   941  199.851222  17751.730469  ...  15074.570312   6.120600e+09
# 60   443  943.794582  17891.500000  ...  15099.179688   7.480170e+09
# 61   416  742.838942  17910.369141  ...  15095.139648   5.090570e+09
# 62   544  305.286765  17930.810547  ...  15011.349609   5.441060e+09
#
#        DOW_Close   DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  \
# 58  37545.328125  212420000.0  4774.750000  2.513910e+09           0        0
# 59  37545.328125  212420000.0  4774.750000  2.513910e+09           0        0
# 60  37656.519531  245530000.0  4781.580078  2.748450e+09           0        0
# 61  37710.101562  199550000.0  4783.350098  2.698860e+09           0        0
# 62  37689.539062  234570000.0  4769.830078  3.126060e+09           0        0
#
#     自營商買賣超股數   淨值(元)
# 58       117  31.195
# 59   115,701  31.230
# 60   -74,290  31.160
# 61   -95,342  30.970
# 62  -107,050  30.670
#
# [5 rows x 21 columns]

# %%
# 漲跌幅（＄）要往未來平移一天，才能確保是在預測

# Remove the first row from '漲跌幅' column and reindex it
df_101112['漲跌幅'] = df_101112['漲跌幅'].shift(-1)

# Remove the last row
df_101112 = df_101112.iloc[:-1]

# Drop rows where '漲跌幅' is NaN (which would only be the last row now)
df_101112 = df_101112.dropna(subset=['漲跌幅'])

# Convert "漲跌幅" column to numeric
df_101112['漲跌幅'] = df_101112['漲跌幅'].str.replace('%', '').astype(float) / 100

df_101112 = df_101112.drop("日期", axis = 1)

# Display the resulting df_101112
print(df_101112.head())
print(df_101112.tail())
# Out:
#       漲跌幅         AI    CHATGPT   輝達        台積電    成交股數  成交筆數      大戶與散戶比例  \
# 0 -0.0083  34.857143  24.571429  6.0  21.714286   34512   837    41.232975
# 1 -0.0203  33.714286  24.142857  6.0  21.428571   31862   965    33.017617
# 2  0.0032  32.571429  23.714286  6.0  21.142857  249091    90  2767.677778
# 3 -0.0075  31.428571  23.285714  6.0  20.857143  428305   637   672.378336
# 4  0.0241  30.285714  22.857143  6.0  20.571429  118427   450   263.171111
#
#        TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume     DOW_Close  \
# 0  16557.310547    2669600  13307.769531   4.554700e+09  33433.351562
# 1  16454.339844    2697100  13059.469727   4.684310e+09  33002.378906
# 2  16273.379883    2624800  13236.009766   4.308070e+09  33129.550781
# 3  16453.519531    2503200  13219.830078   4.167470e+09  33119.570312
# 4  16520.570312    2296800  13431.339844   4.309420e+09  33407.578125
#
#     DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數  \
# 0  275630000.0  4288.390137  3.938660e+09           0        0   -11,165
# 1  293450000.0  4229.450195  3.953830e+09           0        0   -14,138
# 2  287030000.0  4263.750000  3.777600e+09           0        0   -63,000
# 3  277250000.0  4258.189941  3.581470e+09           0        0  -271,452
# 4  332990000.0  4308.500000  3.902030e+09           0        0   -44,029
#
#    淨值(元)
# 0  28.49
# 1  27.94
# 2  28.02
# 3  27.81
# 4  28.17
#        漲跌幅         AI    CHATGPT        輝達        台積電    成交股數  成交筆數  \
# 57  0.0058  38.714286  39.000000  4.000000  21.285714  249407   631
# 58 -0.0023  38.571429  38.571429  3.857143  21.142857   69902   627
# 59  0.0019  38.142857  38.142857  3.714286  21.285714  188060   941
# 60  0.0000  37.714286  37.714286  3.571429  21.428571  418101   443
# 61 -0.0019  37.285714  37.285714  3.428571  21.571429  309021   416
#
#        大戶與散戶比例      TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  \
# 57  395.256735  17596.630859    3700300  14992.969727   4.796600e+09
# 58  111.486443  17604.839844    3027400  15074.570312   6.120600e+09
# 59  199.851222  17751.730469    2900000  15074.570312   6.120600e+09
# 60  943.794582  17891.500000    3378000  15099.179688   7.480170e+09
# 61  742.838942  17910.369141    3289700  15095.139648   5.090570e+09
#
#        DOW_Close   DOW_Volume     SP_Close     SP_Volume  外資自營商買賣超股數  投信買賣超股數  \
# 57  37385.968750  252970000.0  4754.629883  3.046770e+09           0        0
# 58  37545.328125  212420000.0  4774.750000  2.513910e+09           0        0
# 59  37545.328125  212420000.0  4774.750000  2.513910e+09           0        0
# 60  37656.519531  245530000.0  4781.580078  2.748450e+09           0        0
# 61  37710.101562  199550000.0  4783.350098  2.698860e+09           0        0
#
#    自營商買賣超股數   淨值(元)
# 57   98,370  31.080
# 58      117  31.195
# 59  115,701  31.230
# 60  -74,290  31.160
# 61  -95,342  30.970

# %%
# 存檔備份
df_101112.to_csv("/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/df_101112.csv")

# %% [markdown]
# <h1>資料分析
# <h5> 分別分析 5、7、10 天為區間，漲跌幅與各個指標的相關性

# %%
# 以 5 天為群組

import pandas as pd

# Create an empty DataFrame for storing correlations
columns_101112 = df_101112.columns
df_101112_5day_corr = pd.DataFrame(columns=columns_101112[1:])

# Define a function to calculate correlations
def calculate_correlations(df, corr_df, group_size):
    n_rows = df.shape[0]
    for i in range(0, n_rows, group_size):
        df_group = df.iloc[i:i + group_size]
        if df_group.shape[0] > 1:  # Ensure there are at least two rows to calculate correlation
            corr = df_group.corr()
            first_row = corr.iloc[0]
            first_row_df = pd.DataFrame(first_row).T
            corr_df = pd.concat([corr_df, first_row_df], ignore_index=True)
    return corr_df

# Calculate correlations for "AI" column
df_101112_5day_corr = calculate_correlations(df_101112, df_101112_5day_corr, 5)

# 空值補0
df_101112_5day_corr = df_101112_5day_corr.fillna(0)

# Drop "漲跌幅" column
df_101112_5day_corr = df_101112_5day_corr.drop(columns=['漲跌幅'], errors='ignore')

# Save the result to a CSV file
df_101112_5day_corr.to_csv('/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/df_101112_5day_corr.csv', index=False)

# Display the result
print(df_101112_5day_corr)
# Out:
#           AI   CHATGPT        輝達       台積電      成交股數      成交筆數   大戶與散戶比例  \
# 0  -0.735622 -0.735622  0.000000 -0.735622  0.091220 -0.650924  0.205047
# 1  -0.201589  0.487876  0.097808  0.239139  0.460503  0.758143 -0.168857
# 2  -0.629516  0.844891 -0.868354 -0.877733 -0.581032 -0.463303 -0.221973
# 3   0.518646  0.323721  0.000000  0.323721  0.014256  0.019825  0.090769
# 4  -0.834161 -0.078171  0.834161 -0.765759  0.887600 -0.623385  0.698433
# 5   0.628734 -0.576262  0.738798 -0.738798 -0.249377  0.149353 -0.249640
# 6   0.101005  0.189405  0.526466 -0.196098 -0.178062 -0.296974 -0.325622
# 7  -0.574496  0.765734  0.747176  0.673054  0.485825 -0.746636  0.878139
# 8  -0.549326 -0.475134 -0.530073 -0.025680  0.440920  0.382645 -0.062975
# 9  -0.730410  0.544264 -0.183344  0.800852  0.485430 -0.139145  0.023650
# 10 -0.471546 -0.556859  0.556859  0.496994  0.263305 -0.496086  0.600206
# 11  0.159241 -0.308578 -0.308578 -0.695947 -0.046489 -0.193484  0.132706
# 12  1.000000  1.000000  1.000000 -1.000000  1.000000  1.000000  1.000000
#
#     TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  DOW_Close  DOW_Volume  \
# 0   0.020099  -0.861070      0.878070      -0.554516   0.597011    0.769789
# 1  -0.982514   0.324751      0.512775      -0.505856   0.912260   -0.766781
# 2  -0.713783  -0.710779     -0.335849      -0.114987  -0.638925    0.912009
# 3  -0.977655   0.129026     -0.240100       0.036822  -0.112684   -0.108265
# 4  -0.475610   0.264432     -0.460576       0.957196  -0.302905    0.926638
# 5   0.569686   0.076653      0.956929       0.378037   0.928614    0.435191
# 6  -0.419576  -0.633861      0.540626       0.263398   0.397837   -0.032343
# 7   0.701968  -0.232901      0.339675      -0.496112  -0.116617   -0.477721
# 8  -0.192779  -0.772658      0.918837      -0.715633  -0.386510   -0.487617
# 9   0.515544  -0.686166      0.628328       0.137468   0.499186    0.497569
# 10 -0.674518  -0.360384     -0.242008       0.124392  -0.073540   -0.061778
# 11  0.112548  -0.525341      0.779818      -0.674641   0.729464   -0.662708
# 12 -1.000000   1.000000      1.000000       1.000000  -1.000000    1.000000
#
#     SP_Close  SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數     淨值(元)
# 0   0.826447   0.002207         0.0      0.0         0  0.200776
# 1   0.906021  -0.040408         0.0      0.0         0  0.474379
# 2  -0.514971   0.049711         0.0      0.0         0 -0.582156
# 3  -0.144254   0.920512         0.0      0.0         0 -0.181943
# 4  -0.352583   0.984027         0.0      0.0         0 -0.346626
# 5   0.952740   0.775794         0.0      0.0         0  0.956723
# 6   0.365673  -0.080356         0.0      0.0         0  0.544152
# 7   0.809723  -0.501269         0.0      0.0         0 -0.052178
# 8   0.138070  -0.280122         0.0      0.0         0 -0.031312
# 9   0.616211  -0.741513         0.0      0.0         0  0.552631
# 10 -0.127963   0.047177         0.0      0.0         0 -0.112658
# 11  0.786941  -0.746641         0.0      0.0         0  0.753498
# 12 -1.000000   1.000000         0.0      0.0         0  1.000000

# %%
# 以 7 天為群組

# Create an empty DataFrame for storing correlations
columns_101112 = df_101112.columns
df_101112_7day_corr = pd.DataFrame(columns=columns_101112[1:])

# Define a function to calculate correlations
def calculate_correlations(df, corr_df, group_size):
    n_rows = df.shape[0]
    for i in range(0, n_rows, group_size):
        df_group = df.iloc[i:i + group_size]
        if df_group.shape[0] > 1:  # Ensure there are at least two rows to calculate correlation
            corr = df_group.corr()
            first_row = corr.iloc[0]
            first_row_df = pd.DataFrame(first_row).T
            corr_df = pd.concat([corr_df, first_row_df], ignore_index=True)
    return corr_df

# Calculate correlations for "AI" column
df_101112_7day_corr = calculate_correlations(df_101112, df_101112_7day_corr, 7)

# 空值補0
df_101112_7day_corr = df_101112_7day_corr.fillna(0)

# Drop "漲跌幅" column
df_101112_7day_corr = df_101112_7day_corr.drop(columns=['漲跌幅'], errors='ignore')

# Save the result to a CSV file
df_101112_7day_corr.to_csv('/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/df_101112_7day_corr.csv', index=False)

# Display the result
print(df_101112_7day_corr)
# Out:
#          AI   CHATGPT        輝達       台積電      成交股數      成交筆數   大戶與散戶比例  \
# 0 -0.391799 -0.454869 -0.139449 -0.227390  0.150261 -0.520257  0.221741
# 1  0.320395 -0.079328  0.291583  0.331011  0.206155  0.841074 -0.559447
# 2  0.326530  0.537118  0.000000  0.537118  0.056393 -0.098288  0.102375
# 3 -0.509037  0.252709  0.509037 -0.760788  0.829504 -0.799162  0.745723
# 4 -0.340103  0.296603 -0.306131  0.337596 -0.311478  0.354928 -0.491573
# 5  0.147348  0.488278  0.212888 -0.032968  0.097987 -0.225140  0.129450
# 6 -0.518150  0.070361 -0.553972  0.205339  0.640086  0.066690 -0.010666
# 7 -0.520167 -0.474596  0.474596  0.508179 -0.112097 -0.303707  0.195679
# 8  0.288342  0.263385  0.263385 -0.271468  0.259128  0.295503  0.030441
#
#    TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  DOW_Close  DOW_Volume  \
# 0 -0.137380  -0.205357      0.390993      -0.557821   0.270680    0.531444
# 1  0.294944  -0.526449      0.509336      -0.374156   0.422056   -0.303691
# 2 -0.709938  -0.021902      0.302058       0.149418   0.240084   -0.203736
# 3 -0.845024   0.132848     -0.333573       0.131457  -0.038920    0.279133
# 4 -0.538354  -0.599805      0.043605       0.741323  -0.091915   -0.023703
# 5  0.533925  -0.031280      0.199223       0.048037  -0.026724   -0.017926
# 6  0.430934  -0.477566      0.685662      -0.156455   0.631690    0.313972
# 7 -0.389217  -0.232073      0.062240       0.234488   0.216607    0.175590
# 8 -0.091085   0.009162     -0.187196      -0.230071  -0.384525    0.333804
#
#    SP_Close  SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數     淨值(元)
# 0  0.328863  -0.002078         0.0      0.0         0  0.183269
# 1  0.473990  -0.291287         0.0      0.0         0  0.452113
# 2  0.314887   0.663283         0.0      0.0         0  0.290909
# 3 -0.190732   0.769959         0.0      0.0         0 -0.303329
# 4 -0.039084   0.650367         0.0      0.0         0  0.259921
# 5 -0.121686   0.103146         0.0      0.0         0  0.323563
# 6  0.717992  -0.301760         0.0      0.0         0  0.537090
# 7  0.230890   0.276007         0.0      0.0         0  0.028770
# 8 -0.195595  -0.018379         0.0      0.0         0  0.166341

# %%
# 以 10 天為群組

import pandas as pd

# Create an empty DataFrame for storing correlations
columns_101112 = df_101112.columns
df_101112_10day_corr = pd.DataFrame(columns=columns_101112[1:])

# Define a function to calculate correlations
def calculate_correlations(df, corr_df, group_size):
    n_rows = df.shape[0]
    for i in range(0, n_rows, group_size):
        df_group = df.iloc[i:i + group_size]
        if df_group.shape[0] > 1:  # Ensure there are at least two rows to calculate correlation
            corr = df_group.corr()
            first_row = corr.iloc[0]
            first_row_df = pd.DataFrame(first_row).T
            corr_df = pd.concat([corr_df, first_row_df], ignore_index=True)
    return corr_df

# Calculate correlations for "AI" column
df_101112_10day_corr = calculate_correlations(df_101112, df_101112_10day_corr, 10)

# 空值補0
df_101112_10day_corr = df_101112_10day_corr.fillna(0)

# Drop "漲跌幅" column
df_101112_10day_corr = df_101112_10day_corr.drop(columns=['漲跌幅'], errors='ignore')

# Save the result to a CSV file
df_101112_10day_corr.to_csv('/Users/lomingyi/Documents/NTU/ccClub/期末專案/00737/df_101112_10day_corr.csv', index=False)

# Display the result
print(df_101112_10day_corr)
# Out:
#          AI   CHATGPT        輝達       台積電      成交股數      成交筆數   大戶與散戶比例  \
# 0 -0.349772 -0.018329 -0.027504 -0.041508  0.162645 -0.275635  0.178320
# 1  0.239275  0.486474 -0.441513 -0.418759 -0.174951  0.046447 -0.040035
# 2  0.036611 -0.140589  0.683319 -0.541840  0.098946 -0.280186  0.360289
# 3  0.032152 -0.060873  0.200515 -0.222269 -0.032290 -0.453305  0.013463
# 4 -0.511138 -0.066830 -0.365218  0.107081  0.453057  0.053097 -0.052856
# 5 -0.616275 -0.528311  0.621337  0.616937  0.071291 -0.276320  0.347933
# 6  1.000000  1.000000  1.000000 -1.000000  1.000000  1.000000  1.000000
#
#    TW_Close  TW_Volume  NASDAQ_Close  NASDAQ_Volume  DOW_Close  DOW_Volume  \
# 0 -0.161849  -0.189015      0.411762      -0.471748   0.275622    0.342512
# 1 -0.693834  -0.329665     -0.256735      -0.076785  -0.328629    0.248013
# 2 -0.161817   0.151163      0.165520       0.463409   0.270369    0.554022
# 3 -0.007251  -0.587055      0.513385      -0.259302   0.324341   -0.313928
# 4  0.243835  -0.411991      0.439513      -0.292186  -0.084589   -0.084986
# 5 -0.338945  -0.032622     -0.162117       0.274490   0.076472    0.272415
# 6 -1.000000   1.000000      1.000000       1.000000  -1.000000    1.000000
#
#    SP_Close  SP_Volume  外資自營商買賣超股數  投信買賣超股數  自營商買賣超股數     淨值(元)
# 0  0.343080   0.017834         0.0      0.0         0  0.260069
# 1 -0.279962   0.610309         0.0      0.0         0 -0.284157
# 2  0.231052   0.833071         0.0      0.0         0  0.243741
# 3  0.419980  -0.360183         0.0      0.0         0  0.435038
# 4  0.312428  -0.203869         0.0      0.0         0  0.119013
# 5  0.042210   0.354200         0.0      0.0         0 -0.123596
# 6 -1.000000   1.000000         0.0      0.0         0  1.000000
